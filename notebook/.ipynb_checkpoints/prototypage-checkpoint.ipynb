# %%
import psycopg
conn = psycopg.connect(
    "dbname='chatbot' user='postgres' password='Fuck_2001' host='localhost' port='5432'"
)
cur = conn.cursor()
cur.execute("""
    CREATE TABLE IF NOT EXISTS corpus (
        id SERIAL PRIMARY KEY,
        corpus TEXT,
        embedding FLOAT[]
    )
""")
conn.commit()
conn.close()

# %%
import os

corpus_dir = "data"
texts = []

for filename in os.listdir(corpus_dir):
    if filename.endswith(".txt"):
        with open(os.path.join(corpus_dir, filename), "r", encoding="utf-8") as f:
            texts.append(f.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 6
#       3 corpus_dir = "data"
#       4 texts = []
# ----> 6 for filename in os.listdir(corpus_dir):
#       7     if filename.endswith(".txt"):
#       8         with open(os.path.join(corpus_dir, filename), "r", encoding="utf-8") as f:
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'data'
